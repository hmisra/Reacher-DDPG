# %% [markdown]
# # Continuous Control
#
# ---
#
# In this notebook, you will learn how to use the Unity ML-Agents environment for the second project of the [Deep Reinforcement Learning Nanodegree](https://www.udacity.com/course/deep-reinforcement-learning-nanodegree--nd893) program.
#
# ### 1. Start the Environment
#
# We begin by importing the necessary packages.  If the code cell below returns an error, please revisit the project instructions to double-check that you have installed [Unity ML-Agents](https://github.com/Unity-Technologies/ml-agents/blob/master/docs/Installation.md) and [NumPy](http://www.numpy.org/).

# %%
from unityagents import UnityEnvironment
import numpy as np

# %% [markdown]
# Next, we will start the environment!  **_Before running the code cell below_**, change the `file_name` parameter to match the location of the Unity environment that you downloaded.
#
# - **Mac**: `"path/to/Reacher.app"`
# - **Windows** (x86): `"path/to/Reacher_Windows_x86/Reacher.exe"`
# - **Windows** (x86_64): `"path/to/Reacher_Windows_x86_64/Reacher.exe"`
# - **Linux** (x86): `"path/to/Reacher_Linux/Reacher.x86"`
# - **Linux** (x86_64): `"path/to/Reacher_Linux/Reacher.x86_64"`
# - **Linux** (x86, headless): `"path/to/Reacher_Linux_NoVis/Reacher.x86"`
# - **Linux** (x86_64, headless): `"path/to/Reacher_Linux_NoVis/Reacher.x86_64"`
#
# For instance, if you are using a Mac, then you downloaded `Reacher.app`.  If this file is in the same folder as the notebook, then the line below should appear as follows:
# ```
# env = UnityEnvironment(file_name="Reacher.app")
# ```

# %%
env = UnityEnvironment(file_name='./Reacher-2.app')
# Out:
# INFO:unityagents:
# 'Academy' started successfully!
# Unity Academy name: Academy
#         Number of Brains: 1
#         Number of External Brains : 1
#         Lesson number : 0
#         Reset Parameters :
# 		goal_speed -> 1.0
# 		goal_size -> 5.0
# Unity brain name: ReacherBrain
#         Number of Visual Observations (per agent): 0
#         Vector Observation space type: continuous
#         Vector Observation space size (per agent): 33
#         Number of stacked Vector Observation: 1
#         Vector Action space type: continuous
#         Vector Action space size (per agent): 4
#         Vector Action descriptions: , , ,

# %% [markdown]
# Environments contain **_brains_** which are responsible for deciding the actions of their associated agents. Here we check for the first brain available, and set it as the default brain we will be controlling from Python.

# %%
# get the default brain
brain_name = env.brain_names[0]
brain = env.brains[brain_name]

# %% [markdown]
# ### 2. Examine the State and Action Spaces
#
# In this environment, a double-jointed arm can move to target locations. A reward of `+0.1` is provided for each step that the agent's hand is in the goal location. Thus, the goal of your agent is to maintain its position at the target location for as many time steps as possible.
#
# The observation space consists of `33` variables corresponding to position, rotation, velocity, and angular velocities of the arm.  Each action is a vector with four numbers, corresponding to torque applicable to two joints.  Every entry in the action vector must be a number between `-1` and `1`.
#
# Run the code cell below to print some information about the environment.

# %%
# reset the environment
env_info = env.reset(train_mode=True)[brain_name]

# number of agents
num_agents = len(env_info.agents)
print('Number of agents:', num_agents)

# size of each action
action_size = brain.vector_action_space_size
print('Size of each action:', action_size)

# examine the state space 
states = env_info.vector_observations
state_size = states.shape[1]
print('There are {} agents. Each observes a state with length: {}'.format(states.shape[0], state_size))
print('The state for the first agent looks like:', states[0])
# Out:
# Number of agents: 20
# Size of each action: 4
# There are 20 agents. Each observes a state with length: 33
# The state for the first agent looks like: [ 0.00000000e+00 -4.00000000e+00  0.00000000e+00  1.00000000e+00
#  -0.00000000e+00 -0.00000000e+00 -4.37113883e-08  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00 -1.00000000e+01  0.00000000e+00
#   1.00000000e+00 -0.00000000e+00 -0.00000000e+00 -4.37113883e-08
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  5.75471878e+00 -1.00000000e+00
#   5.55726624e+00  0.00000000e+00  1.00000000e+00  0.00000000e+00
#  -1.68164849e-01]

# %% [markdown]
# ### 3. It's Your Turn!
#
# Now it's your turn to train your own agent to solve the environment!  When training the environment, set `train_mode=True`, so that the line for resetting the environment looks like the following:
# ```python
# env_info = env.reset(train_mode=True)[brain_name]
# ```

# %%
from  collections  import deque
from itertools import count
import time
import torch
from ddpg_agent import Agent
import matplotlib.pyplot as plt
# %matplotlib inline
env_info = env.reset(train_mode=True)[brain_name]
agent = Agent(state_size=state_size, action_size=action_size, random_seed=15)

# %%
def ddpg(n_episodes=3000):
    scores_deque = deque(maxlen=100)
    scores_global = []
        
    for i_episode in range(1, n_episodes+1):
        env_info = env.reset(train_mode=True)[brain_name]      # reset the environment    
        states = env_info.vector_observations                  # get the current state (for each agent)
        scores = np.zeros(num_agents)                          # initialize the score (for each agent)
        agent.reset()
        
        score_average = 0
        timestep = time.time()
        for t in range(3000):
            actions = agent.act(states)
            env_info = env.step(actions)[brain_name]           # send all actions to tne environment
            next_states = env_info.vector_observations         # get next state (for each agent)
            rewards = env_info.rewards                         # get reward (for each agent)
            dones = env_info.local_done                        # see if episode finished
            agent.step(states, actions, rewards, next_states, dones, t)
            states = next_states                               # roll over states to next time step
            scores += rewards                                  # update the score (for each agent)            
            if np.any(dones):                                  # exit loop if episode finished
                break
        
        score = np.mean(scores)
        scores_deque.append(score)
        score_average = np.mean(scores_deque)
        scores_global.append(score)
        
        print('\rEpisode {}, Average Score: {:.2f}, Max: {:.2f}, Min: {:.2f}, Time: {:.2f}'\
              .format(i_episode, score_average, np.max(scores), np.min(scores), time.time() - timestep), end="\n")        
        
        if i_episode % 10 == 0:
            torch.save(agent.actor_local.state_dict(), 'checkpoint_actor.pth')
            torch.save(agent.critic_local.state_dict(), 'checkpoint_critic.pth')
            print('\rEpisode {}\tAverage Score: {:.2f}'.format(i_episode, np.mean(scores_deque)))   
        if score_average>32:
            break
            
    return scores_global

scores = ddpg()

fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(1, len(scores)+1), scores)
plt.ylabel('Score')
plt.xlabel('Episode #')
plt.show()
# Out:
# Episode 1, Average Score: 0.00, Max: 0.00, Min: 0.00, Time: 13.72
# Episode 2, Average Score: 0.01, Max: 0.13, Min: 0.00, Time: 14.10
# Episode 3, Average Score: 0.01, Max: 0.08, Min: 0.00, Time: 14.37
# Episode 4, Average Score: 0.09, Max: 0.85, Min: 0.00, Time: 14.45
# Episode 5, Average Score: 0.24, Max: 1.39, Min: 0.02, Time: 15.84
# Episode 6, Average Score: 0.21, Max: 0.99, Min: 0.00, Time: 15.59
# Episode 7, Average Score: 0.22, Max: 0.93, Min: 0.00, Time: 15.70
# Episode 8, Average Score: 0.26, Max: 1.06, Min: 0.00, Time: 15.21
# Episode 9, Average Score: 0.29, Max: 1.68, Min: 0.12, Time: 15.83
# Episode 10, Average Score: 0.33, Max: 1.46, Min: 0.00, Time: 16.63
# Episode 10	Average Score: 0.33
# Episode 11, Average Score: 0.36, Max: 2.05, Min: 0.00, Time: 17.20
# Episode 12, Average Score: 0.41, Max: 2.33, Min: 0.05, Time: 16.35
# Episode 13, Average Score: 0.44, Max: 1.54, Min: 0.12, Time: 16.55
# Episode 14, Average Score: 0.46, Max: 2.56, Min: 0.05, Time: 17.22
# Episode 15, Average Score: 0.51, Max: 2.11, Min: 0.23, Time: 17.26
# Episode 16, Average Score: 0.51, Max: 1.80, Min: 0.07, Time: 17.53
# Episode 17, Average Score: 0.54, Max: 1.64, Min: 0.18, Time: 18.06
# Episode 18, Average Score: 0.55, Max: 1.46, Min: 0.30, Time: 17.65
# Episode 19, Average Score: 0.58, Max: 2.74, Min: 0.29, Time: 17.91
# Episode 20, Average Score: 0.60, Max: 1.71, Min: 0.30, Time: 21.31
# Episode 20	Average Score: 0.60
# Episode 21, Average Score: 0.61, Max: 1.86, Min: 0.25, Time: 18.48
# Episode 22, Average Score: 0.62, Max: 1.56, Min: 0.00, Time: 19.43
# Episode 23, Average Score: 0.62, Max: 1.52, Min: 0.21, Time: 19.85
# Episode 24, Average Score: 0.63, Max: 1.51, Min: 0.20, Time: 19.34
# Episode 25, Average Score: 0.64, Max: 1.65, Min: 0.09, Time: 20.42
# Episode 26, Average Score: 0.65, Max: 1.78, Min: 0.14, Time: 21.14
# Episode 27, Average Score: 0.66, Max: 2.09, Min: 0.38, Time: 20.27
# Episode 28, Average Score: 0.69, Max: 2.35, Min: 0.24, Time: 21.36
# Episode 29, Average Score: 0.71, Max: 2.99, Min: 0.59, Time: 21.80
# Episode 30, Average Score: 0.75, Max: 2.77, Min: 0.55, Time: 20.79
# Episode 30	Average Score: 0.75
# Episode 31, Average Score: 0.77, Max: 2.70, Min: 0.27, Time: 20.95
# Episode 32, Average Score: 0.79, Max: 2.65, Min: 0.62, Time: 21.30
# Episode 33, Average Score: 0.80, Max: 2.19, Min: 0.10, Time: 21.80
# Episode 34, Average Score: 0.83, Max: 2.63, Min: 0.88, Time: 23.10
# Episode 35, Average Score: 0.85, Max: 3.33, Min: 0.11, Time: 22.79
# Episode 36, Average Score: 0.87, Max: 2.47, Min: 0.33, Time: 23.02
# Episode 37, Average Score: 0.88, Max: 2.28, Min: 0.17, Time: 22.86
# Episode 38, Average Score: 0.89, Max: 2.52, Min: 0.49, Time: 23.25
# Episode 39, Average Score: 0.91, Max: 2.89, Min: 0.53, Time: 23.19
# Episode 40, Average Score: 0.92, Max: 3.13, Min: 0.54, Time: 23.43
# Episode 40	Average Score: 0.92
# Episode 41, Average Score: 0.93, Max: 2.76, Min: 0.60, Time: 23.50
# Episode 42, Average Score: 0.97, Max: 4.26, Min: 0.80, Time: 23.88
# Episode 43, Average Score: 0.99, Max: 5.91, Min: 0.61, Time: 26.26
# Episode 44, Average Score: 1.02, Max: 3.91, Min: 0.58, Time: 27.00
# Episode 45, Average Score: 1.03, Max: 3.26, Min: 0.68, Time: 25.52
# Episode 46, Average Score: 1.04, Max: 3.15, Min: 0.30, Time: 25.31
# Episode 47, Average Score: 1.06, Max: 3.73, Min: 0.68, Time: 25.21
# Episode 48, Average Score: 1.08, Max: 4.90, Min: 0.40, Time: 25.28
# Episode 49, Average Score: 1.11, Max: 4.52, Min: 0.37, Time: 25.92
# Episode 50, Average Score: 1.14, Max: 5.95, Min: 0.89, Time: 26.21
# Episode 50	Average Score: 1.14
# Episode 51, Average Score: 1.17, Max: 6.41, Min: 1.40, Time: 25.47
# Episode 52, Average Score: 1.21, Max: 4.98, Min: 0.93, Time: 25.35
# Episode 53, Average Score: 1.24, Max: 5.04, Min: 2.11, Time: 25.30
# Episode 54, Average Score: 1.26, Max: 4.33, Min: 0.67, Time: 25.47
# Episode 55, Average Score: 1.30, Max: 5.66, Min: 1.80, Time: 25.29
# Episode 56, Average Score: 1.35, Max: 5.99, Min: 1.80, Time: 25.40
# Episode 57, Average Score: 1.40, Max: 6.97, Min: 2.94, Time: 26.98
# Episode 58, Average Score: 1.45, Max: 6.84, Min: 3.00, Time: 26.32
# Episode 59, Average Score: 1.50, Max: 6.38, Min: 3.20, Time: 26.11
# Episode 60, Average Score: 1.55, Max: 7.02, Min: 1.15, Time: 26.07
# Episode 60	Average Score: 1.55
# Episode 61, Average Score: 1.60, Max: 7.16, Min: 2.43, Time: 25.59
# Episode 62, Average Score: 1.66, Max: 11.04, Min: 2.74, Time: 25.85
# Episode 63, Average Score: 1.69, Max: 6.25, Min: 1.49, Time: 26.19
# Episode 64, Average Score: 1.73, Max: 6.64, Min: 1.52, Time: 26.50
# Episode 65, Average Score: 1.78, Max: 7.99, Min: 2.82, Time: 28.75
# Episode 66, Average Score: 1.83, Max: 8.53, Min: 1.91, Time: 28.09
# Episode 67, Average Score: 1.87, Max: 7.22, Min: 1.81, Time: 27.27
# Episode 68, Average Score: 1.92, Max: 7.85, Min: 3.17, Time: 28.38
# Episode 69, Average Score: 1.95, Max: 9.18, Min: 1.77, Time: 28.96
# Episode 70, Average Score: 1.99, Max: 7.26, Min: 0.66, Time: 27.21
# Episode 70	Average Score: 1.99
# Episode 71, Average Score: 2.03, Max: 11.86, Min: 2.61, Time: 27.68
# Episode 72, Average Score: 2.09, Max: 10.86, Min: 2.89, Time: 26.64
# Episode 73, Average Score: 2.15, Max: 9.18, Min: 1.93, Time: 26.77
# Episode 74, Average Score: 2.19, Max: 8.67, Min: 2.96, Time: 28.70
# Episode 75, Average Score: 2.25, Max: 9.52, Min: 3.35, Time: 31.60
# Episode 76, Average Score: 2.29, Max: 10.54, Min: 2.86, Time: 31.06
# Episode 77, Average Score: 2.34, Max: 12.40, Min: 2.85, Time: 31.61
# Episode 78, Average Score: 2.40, Max: 12.72, Min: 3.39, Time: 28.52
# Episode 79, Average Score: 2.45, Max: 12.43, Min: 3.81, Time: 28.98
# Episode 80, Average Score: 2.52, Max: 18.08, Min: 4.13, Time: 27.77
# Episode 80	Average Score: 2.52
# Episode 81, Average Score: 2.57, Max: 11.78, Min: 3.06, Time: 29.56
# Episode 82, Average Score: 2.64, Max: 16.63, Min: 3.93, Time: 30.48
# Episode 83, Average Score: 2.69, Max: 10.96, Min: 4.75, Time: 31.93
# Episode 84, Average Score: 2.75, Max: 11.19, Min: 2.10, Time: 31.26
# Episode 85, Average Score: 2.80, Max: 10.74, Min: 2.78, Time: 31.25
# Episode 86, Average Score: 2.86, Max: 12.43, Min: 5.10, Time: 35.00
# Episode 87, Average Score: 2.91, Max: 11.83, Min: 2.06, Time: 32.96
# Episode 88, Average Score: 2.97, Max: 12.58, Min: 5.00, Time: 29.82
# Episode 89, Average Score: 3.03, Max: 25.26, Min: 2.05, Time: 30.65
# Episode 90, Average Score: 3.09, Max: 16.05, Min: 4.03, Time: 35.18
# Episode 90	Average Score: 3.09
# Episode 91, Average Score: 3.15, Max: 15.87, Min: 4.99, Time: 33.95
# Episode 92, Average Score: 3.20, Max: 13.89, Min: 5.20, Time: 33.18
# Episode 93, Average Score: 3.27, Max: 18.12, Min: 5.43, Time: 32.39
# Episode 94, Average Score: 3.32, Max: 13.19, Min: 4.30, Time: 33.18
# Episode 95, Average Score: 3.38, Max: 12.68, Min: 5.44, Time: 30.62
# Episode 96, Average Score: 3.43, Max: 17.05, Min: 4.52, Time: 34.42
# Episode 97, Average Score: 3.50, Max: 15.74, Min: 6.02, Time: 32.89
# Episode 98, Average Score: 3.57, Max: 15.87, Min: 5.89, Time: 35.12
# Episode 99, Average Score: 3.63, Max: 17.47, Min: 7.17, Time: 33.43
# Episode 100, Average Score: 3.69, Max: 13.94, Min: 3.92, Time: 34.16
# Episode 100	Average Score: 3.69
# Episode 101, Average Score: 3.80, Max: 13.19, Min: 5.57, Time: 37.44
# Episode 102, Average Score: 3.91, Max: 14.99, Min: 5.43, Time: 25.68
# Episode 103, Average Score: 4.03, Max: 19.71, Min: 5.60, Time: 25.85
# Episode 104, Average Score: 4.16, Max: 21.36, Min: 8.30, Time: 27.31
# Episode 105, Average Score: 4.29, Max: 18.96, Min: 8.90, Time: 26.49
# Episode 106, Average Score: 4.43, Max: 18.53, Min: 8.61, Time: 26.72
# Episode 107, Average Score: 4.55, Max: 19.65, Min: 6.55, Time: 28.48
# Episode 108, Average Score: 4.68, Max: 22.94, Min: 8.21, Time: 27.95
# Episode 109, Average Score: 4.81, Max: 18.67, Min: 9.39, Time: 26.46
# Episode 110, Average Score: 4.93, Max: 19.39, Min: 5.33, Time: 26.24
# Episode 110	Average Score: 4.93
# Episode 111, Average Score: 5.06, Max: 21.19, Min: 8.90, Time: 26.10
# Episode 112, Average Score: 5.19, Max: 20.53, Min: 8.01, Time: 26.21
# Episode 113, Average Score: 5.32, Max: 20.06, Min: 7.20, Time: 26.57
# Episode 114, Average Score: 5.47, Max: 20.05, Min: 11.25, Time: 26.90
# Episode 115, Average Score: 5.60, Max: 19.90, Min: 6.42, Time: 26.95
# Episode 116, Average Score: 5.74, Max: 21.69, Min: 3.56, Time: 28.57
# Episode 117, Average Score: 5.88, Max: 19.76, Min: 8.32, Time: 27.05
# Episode 118, Average Score: 6.04, Max: 23.16, Min: 8.87, Time: 26.93
# Episode 119, Average Score: 6.19, Max: 25.07, Min: 6.20, Time: 27.31
# Episode 120, Average Score: 6.33, Max: 21.98, Min: 7.73, Time: 27.32
# Episode 120	Average Score: 6.33
# Episode 121, Average Score: 6.49, Max: 25.60, Min: 7.86, Time: 26.52
# Episode 122, Average Score: 6.67, Max: 36.91, Min: 6.63, Time: 25.92
# Episode 123, Average Score: 6.86, Max: 24.46, Min: 9.71, Time: 25.94
# Episode 124, Average Score: 7.06, Max: 28.92, Min: 9.04, Time: 25.93
# Episode 125, Average Score: 7.24, Max: 26.74, Min: 5.42, Time: 26.08
# Episode 126, Average Score: 7.43, Max: 28.69, Min: 6.04, Time: 26.02
# Episode 127, Average Score: 7.64, Max: 29.16, Min: 13.60, Time: 26.05
# Episode 128, Average Score: 7.83, Max: 29.91, Min: 11.80, Time: 26.07
# Episode 129, Average Score: 8.04, Max: 35.12, Min: 14.10, Time: 26.38
# Episode 130, Average Score: 8.31, Max: 39.01, Min: 17.90, Time: 26.70
# Episode 130	Average Score: 8.31
# Episode 131, Average Score: 8.58, Max: 36.30, Min: 23.87, Time: 26.83
# Episode 132, Average Score: 8.83, Max: 36.80, Min: 18.11, Time: 29.19
# Episode 133, Average Score: 9.11, Max: 35.08, Min: 17.79, Time: 28.29
# Episode 134, Average Score: 9.40, Max: 38.06, Min: 19.47, Time: 29.03
# Episode 135, Average Score: 9.70, Max: 36.55, Min: 19.35, Time: 30.30
# Episode 136, Average Score: 10.03, Max: 39.15, Min: 21.46, Time: 29.23
# Episode 137, Average Score: 10.35, Max: 37.98, Min: 23.37, Time: 31.21
# Episode 138, Average Score: 10.66, Max: 39.49, Min: 24.46, Time: 35.53
# Episode 139, Average Score: 10.98, Max: 38.59, Min: 24.84, Time: 35.81
# Episode 140, Average Score: 11.30, Max: 38.14, Min: 28.59, Time: 32.75
# Episode 140	Average Score: 11.30
# Episode 141, Average Score: 11.61, Max: 39.43, Min: 24.94, Time: 32.72
# Episode 142, Average Score: 11.90, Max: 37.03, Min: 27.37, Time: 34.01
# Episode 143, Average Score: 12.22, Max: 39.39, Min: 27.75, Time: 33.83
# Episode 144, Average Score: 12.55, Max: 38.90, Min: 27.42, Time: 32.19
# Episode 145, Average Score: 12.88, Max: 38.57, Min: 29.49, Time: 30.14
# Episode 146, Average Score: 13.21, Max: 38.30, Min: 29.85, Time: 29.98
# Episode 147, Average Score: 13.53, Max: 38.80, Min: 30.66, Time: 32.37
# Episode 148, Average Score: 13.84, Max: 38.03, Min: 22.08, Time: 34.21
# Episode 149, Average Score: 14.16, Max: 38.17, Min: 26.26, Time: 35.42
# Episode 150, Average Score: 14.46, Max: 37.55, Min: 26.58, Time: 30.23
# Episode 150	Average Score: 14.46
# Episode 151, Average Score: 14.77, Max: 39.04, Min: 24.18, Time: 27.60
# Episode 152, Average Score: 15.05, Max: 38.58, Min: 19.32, Time: 26.32
# Episode 153, Average Score: 15.34, Max: 38.87, Min: 16.94, Time: 26.05
# Episode 154, Average Score: 15.65, Max: 39.39, Min: 28.33, Time: 26.01
# Episode 155, Average Score: 15.92, Max: 38.56, Min: 19.93, Time: 26.45
# Episode 156, Average Score: 16.22, Max: 39.34, Min: 22.33, Time: 26.58
# Episode 157, Average Score: 16.52, Max: 39.08, Min: 27.93, Time: 25.93
# Episode 158, Average Score: 16.83, Max: 39.33, Min: 29.59, Time: 27.31
# Episode 159, Average Score: 17.14, Max: 39.33, Min: 30.98, Time: 26.40
# Episode 160, Average Score: 17.43, Max: 37.82, Min: 28.92, Time: 27.20
# Episode 160	Average Score: 17.43
# Episode 161, Average Score: 17.73, Max: 37.97, Min: 25.32, Time: 27.80
# Episode 162, Average Score: 18.04, Max: 39.48, Min: 29.23, Time: 26.02
# Episode 163, Average Score: 18.36, Max: 38.80, Min: 32.84, Time: 26.67
# Episode 164, Average Score: 18.69, Max: 39.46, Min: 33.87, Time: 26.21
# Episode 165, Average Score: 19.02, Max: 38.94, Min: 33.50, Time: 26.03
# Episode 166, Average Score: 19.34, Max: 39.52, Min: 32.15, Time: 26.96
# Episode 167, Average Score: 19.65, Max: 38.32, Min: 32.18, Time: 26.77
# Episode 168, Average Score: 19.96, Max: 38.83, Min: 33.31, Time: 26.97
# Episode 169, Average Score: 20.28, Max: 38.65, Min: 34.33, Time: 26.82
# Episode 170, Average Score: 20.61, Max: 39.56, Min: 35.20, Time: 26.40
# Episode 170	Average Score: 20.61
# Episode 171, Average Score: 20.92, Max: 38.52, Min: 34.15, Time: 28.15
# Episode 172, Average Score: 21.22, Max: 39.10, Min: 31.20, Time: 26.84
# Episode 173, Average Score: 21.53, Max: 38.99, Min: 33.56, Time: 26.97
# Episode 174, Average Score: 21.84, Max: 39.59, Min: 31.21, Time: 27.59
# Episode 175, Average Score: 22.16, Max: 39.53, Min: 33.90, Time: 27.29
# Episode 176, Average Score: 22.48, Max: 39.61, Min: 32.61, Time: 27.32
# Episode 177, Average Score: 22.80, Max: 39.32, Min: 33.58, Time: 26.45
# Episode 178, Average Score: 23.09, Max: 38.80, Min: 30.71, Time: 27.11
# Episode 179, Average Score: 23.42, Max: 39.63, Min: 36.62, Time: 27.46
# Episode 180, Average Score: 23.72, Max: 39.34, Min: 34.59, Time: 27.82
# Episode 180	Average Score: 23.72
# Episode 181, Average Score: 24.02, Max: 39.51, Min: 35.09, Time: 29.74
# Episode 182, Average Score: 24.33, Max: 39.36, Min: 36.74, Time: 28.29
# Episode 183, Average Score: 24.63, Max: 39.65, Min: 33.70, Time: 28.21
# Episode 184, Average Score: 24.93, Max: 39.50, Min: 35.22, Time: 29.25
# Episode 185, Average Score: 25.25, Max: 39.46, Min: 35.14, Time: 26.49
# Episode 186, Average Score: 25.55, Max: 39.54, Min: 34.71, Time: 29.21
# Episode 187, Average Score: 25.86, Max: 39.60, Min: 37.20, Time: 27.73
# Episode 188, Average Score: 26.16, Max: 39.43, Min: 36.78, Time: 27.89
# Episode 189, Average Score: 26.45, Max: 39.08, Min: 34.76, Time: 29.87
# Episode 190, Average Score: 26.75, Max: 39.59, Min: 35.14, Time: 28.29
# Episode 190	Average Score: 26.75
# Episode 191, Average Score: 27.05, Max: 39.58, Min: 37.21, Time: 28.06
# Episode 192, Average Score: 27.35, Max: 39.65, Min: 35.95, Time: 28.30
# Episode 193, Average Score: 27.63, Max: 39.35, Min: 34.43, Time: 27.84
# Episode 194, Average Score: 27.93, Max: 39.20, Min: 34.10, Time: 28.88
# Episode 195, Average Score: 28.22, Max: 39.64, Min: 34.52, Time: 29.24
# Episode 196, Average Score: 28.49, Max: 39.45, Min: 25.45, Time: 31.03
# Episode 197, Average Score: 28.76, Max: 39.07, Min: 35.14, Time: 30.31
# Episode 198, Average Score: 29.05, Max: 39.64, Min: 36.98, Time: 29.72
# Episode 199, Average Score: 29.32, Max: 39.04, Min: 35.28, Time: 29.59
# Episode 200, Average Score: 29.60, Max: 39.37, Min: 37.10, Time: 28.68
# Episode 200	Average Score: 29.60
# Episode 201, Average Score: 29.88, Max: 39.56, Min: 34.20, Time: 27.43
# Episode 202, Average Score: 30.13, Max: 39.07, Min: 32.70, Time: 27.06
# Episode 203, Average Score: 30.38, Max: 39.09, Min: 31.02, Time: 26.78
# Episode 204, Average Score: 30.63, Max: 39.53, Min: 34.55, Time: 27.48
# Episode 205, Average Score: 30.88, Max: 39.52, Min: 36.30, Time: 26.61
# Episode 206, Average Score: 31.12, Max: 39.59, Min: 35.48, Time: 27.11
# Episode 207, Average Score: 31.39, Max: 39.57, Min: 36.37, Time: 27.25
# Episode 208, Average Score: 31.62, Max: 39.21, Min: 35.11, Time: 27.11
# Episode 209, Average Score: 31.88, Max: 39.62, Min: 36.19, Time: 28.03
# Episode 210, Average Score: 32.13, Max: 39.39, Min: 36.18, Time: 27.75
# Episode 210	Average Score: 32.13
